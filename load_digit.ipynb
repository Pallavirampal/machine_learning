# %% [markdown]
# <a href="https://colab.research.google.com/github/Pallavirampal/machine_learning/blob/master/load_digit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler

# %%
x = load_digits()
features = x.data
target = x.target
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fcb8eaa498c0> in <module>()
# ----> 1 x = load_digits()
#       2 features = x.data
#       3 target = x.target
#
# NameError: name 'load_digits' is not defined

# %%
for i,featurevalues in enumerate(features):
  print(i,featurevalues)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=1,multi_class='ovr')
clf.fit(xtrain,ytrain)
pred = clf.predict(xtest)
org = ytest
score = clf.score(xtest,ytest)
score

# %%
new = [[.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9,.5,.6,.8,.9]]
obs = clf.predict(new)
obs
# Out:
# array([4])

# %%
obs = clf.predict_proba(new)
obs
# Out:
# array([[4.72505846e-06, 1.16566668e-02, 2.27386961e-06, 1.04823654e-02,
#         5.21144986e-01, 7.69925298e-02, 8.32820017e-02, 2.73060780e-01,
#         4.31559195e-03, 1.90580801e-02]])

# %%
import matplotlib.pyplot as plt
plt.plot(pred,org)
